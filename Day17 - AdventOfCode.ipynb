# %%
with open('Input17') as f:
    hot_gas = list(f.read())

# %%
hot_gas.remove('\n')

# %%
hot_gas
# Out:
# ['>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '>',
#  '<',
#  '>',
#  '>',
#  '>',
#  '<',
#  '>',
#  '<',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '>',
#  '<',
#  '>',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '<',
#  '>',
#  '<',
#  '>',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '<',
#  '>',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '>',
#  '<',
#  '<',
#  '<',
#  '>',
#  '<',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '>',
#  '>',
#  '>',
#  '<',
#  '<',
#  '<',
#  '>',
#  '<',
#  '<',
#  '>',
#  '<',
#  '<',
#  '>',
#  '>',
# ...
